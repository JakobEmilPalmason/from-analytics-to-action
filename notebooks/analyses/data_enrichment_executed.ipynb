# %% [markdown]
# # Data Enrichment: Building the Combined European Film Dataset
#
# This notebook documents how we enriched our original European film dataset (2,000 films from IMDb) with three additional data sources to enable deeper analysis of audience reception and commercial performance.
#
# ## Data Sources
#
# | Source | What it adds | Coverage |
# |--------|-------------|----------|
# | **Original dataset** | IMDb metadata (title, genre, country, cast, plot, keywords, ratings) | 2,000 films |
# | **TMDb API** | Budget, revenue, popularity, tagline, production countries | 89.5% found, 53% have financials |
# | **IMDb GraphQL API** | Per-star rating distributions (vote counts for each score 1–10) | 99.95% coverage |
# | **MovieLens 32M** | User-level ratings, standard deviation, user-contributed tags | 79.7% found, 72.5% have tags |
#
# ## Why these sources?
#
# Our original dataset had average IMDb ratings but no insight into **how** people rated films — are ratings concentrated in the middle, or split between love and hate? We also had no financial data to connect audience reception to commercial outcomes.
#
# - **IMDb rating distributions** let us measure **polarization** — films that divide audiences
# - **TMDb budget/revenue** lets us analyze **commercial performance and ROI**
# - **MovieLens** gives us a second rating platform with **user-level granularity and tags**

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 70)

# %% [markdown]
# ## 1. Load the Raw Sources

# %%
# Original dataset
main = pd.read_csv("../03-data/Movie_50k.csv")
print(f"Original dataset: {len(main)} films, {len(main.columns)} columns")
main.head(3)
# Out:
# Original dataset: 50000 films, 23 columns
#       titleId                                 imdbUrl  \
# 0   tt1821427   https://www.imdb.com/title/tt1821427/
# 1  tt23460232  https://www.imdb.com/title/tt23460232/
# 2   tt1320100   https://www.imdb.com/title/tt1320100/
#
#               originalTitle titleType  releaseYear  runtimeMinutes  isAdult  \
# 0                  Offender     movie       2012.0           102.0    False
# 1                 Bijuterie     movie          NaN             NaN    False
# 2  Kato apo to makigiaz sou     movie       2008.0            90.0    False
#
#    imdbRating  numberOfVotes allCountries mainCountry allLanguages  \
# 0         6.0         4994.0           GB          GB           en
# 1         NaN            NaN           LT          LT          NaN
# 2         4.8           40.0           GR          GR           el
#
#   firstLanguage englishTitle  \
# 0            en     Offender
# 1           NaN          NaN
# 2            el          NaN
#
#                                        topFiveActors  directors  \
# 0  nm3771184 (Tommy Nix), nm4878199 (Jake), nm263...  nm2151723
# 1                                                NaN  nm3786205
# 2  nm1021762 (Niki), nm2573695 (Vicky), nm1041168...  nm1100028
#
#                 writers                                          plotShort  \
# 0             nm1794018  Justice needs to be served at Britain's most n...
# 1  nm6391953, nm6911938  Loreta, a young firecracker, finds herself inv...
# 2             nm1100028  Niki, an employee at a cosmetics shop, wants t...
#
#                                           plotMedium plotLong  \
# 0  When hardened thugs assault his fiancée and ca...      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
#
#                    genres                                           keywords  \
# 0  Crime, Drama, Thriller  teenage boy, male nudity, man hits a woman, ba...
# 1          Crime, Romance                                        love, young
# 2                   Drama                                               home
#
#                                           production
# 0  Revolver Entertainment, Revolver Entertainment...
# 1                                                NaN
# 2  Village Films, Audio Visual Enterprises, PLD P...

# %%
# TMDb enrichment (budget, revenue, popularity)
tmdb = pd.read_csv("../03-data/raw/tmdb_enrichment.csv").drop_duplicates(subset="titleId")
print(f"TMDb data: {len(tmdb)} films")
print(f"  Found on TMDb: {tmdb['tmdb_id'].notna().sum()} ({tmdb['tmdb_id'].notna().mean():.1%})")
print(f"  Has budget: {(tmdb['budget'].fillna(0) > 0).sum()}")
print(f"  Has revenue: {(tmdb['revenue'].fillna(0) > 0).sum()}")
tmdb[tmdb['budget'] > 0].head(3)
# Out:
# TMDb data: 51444 films
#   Found on TMDb: 28933 (56.2%)
#   Has budget: 2441
#   Has revenue: 2166
#      titleId   tmdb_id     budget    revenue  tmdb_popularity  \
# 1  tt2486278  254126.0  2000000.0        0.0           0.7031
# 2  tt1361313   47088.0  7000000.0   453079.0           1.0182
# 4  tt0421229   47880.0   750000.0  1720953.0           0.7032
#
#    tmdb_vote_average  tmdb_vote_count original_language  \
# 1              3.435             23.0                en
# 2              5.800            105.0                en
# 4              6.500             41.0                en
#
#                                    tagline    status spoken_languages  \
# 1     Absence makes the heart grow darkest  Released          English
# 2  They're not gigolos, they're gentlemen.  Released          English
# 4    One Chance Meeting, Two Changed Lives  Released          English
#
#   production_countries
# 1                  NaN
# 2               FR, US
# 4                   GB

# %%
# IMDb rating distributions (per-star vote counts)
imdb_hist = pd.read_csv("../03-data/raw/imdb_rating_distributions.csv").drop_duplicates(subset="titleId")
print(f"IMDb histograms: {len(imdb_hist)} films")
print(f"  Has data: {imdb_hist['totalVotes'].notna().sum()} ({imdb_hist['totalVotes'].notna().mean():.1%})")
imdb_hist.head(3)
# Out:
# IMDb histograms: 50400 films
#   Has data: 50393 (100.0%)
#      titleId  aggregateRating  totalVotes  rating_1  rating_2  rating_3  \
# 0  tt3042384              7.4     62956.0     789.0     426.0     640.0
# 1  tt2486278              3.1       697.0     178.0     116.0     132.0
# 2  tt1361313              5.8      5581.0     234.0     146.0     230.0
#
#    rating_4  rating_5  rating_6  rating_7  rating_8  rating_9  rating_10
# 0    1201.0    2660.0    7072.0   16239.0   18869.0    9655.0     5405.0
# 1      95.0      54.0      31.0      16.0      11.0      10.0       54.0
# 2     466.0     958.0    1432.0    1105.0     519.0     184.0      307.0

# %%
# MovieLens enrichment (user-level ratings + tags)
ml = pd.read_csv("../03-data/raw/movielens_enrichment.csv")
print(f"MovieLens data: {len(ml)} films")
print(f"  Has tags: {ml['ml_tags'].notna().sum()} ({ml['ml_tags'].notna().mean():.1%})")
print(f"  Total ratings: {ml['ml_rating_count'].sum():,.0f}")
ml.head(3)
# Out:
# MovieLens data: 1593 films
#   Has tags: 1451 (91.1%)
#   Total ratings: 2,740,397
#      titleId  ml_rating_count  ml_rating_mean  ml_rating_std  \
# 0  tt0114319            13585        3.363968       0.964193
# 1  tt0112896             4258        2.649131       1.131199
# 2  tt0114388            22251        3.945126       0.967041
#
#    ml_rating_median  ml_rating_0_5  ml_rating_1_0  ml_rating_1_5  \
# 0               3.0            120            382            130
# 1               3.0             98            647            119
# 2               4.0            125            458             69
#
#    ml_rating_2_0  ml_rating_2_5  ml_rating_3_0  ml_rating_3_5  ml_rating_4_0  \
# 0           1083            472           5204            723           3651
# 1            818            245           1322            218            500
# 2            732            257           4033           1163           7653
#
#    ml_rating_4_5  ml_rating_5_0  \
# 0            260           1560
# 1             54            237
# 2           1068           6693
#
#                                              ml_tags
# 0  as good maybe better than original, great cast...
# 1  vampire, vampires, Leslie Nielsen, spoof, funn...
# 2  boring, nothing happens, 18th century, classic...

# %% [markdown]
# ## 2. Merge into Combined Dataset
#
# All sources are joined on `titleId` (IMDb identifier). We use left joins to keep all 2,000 films even if a source doesn't cover them.

# %%
df = main.merge(tmdb, on="titleId", how="left")
df = df.merge(imdb_hist, on="titleId", how="left")
df = df.merge(ml, on="titleId", how="left")

print(f"Combined dataset: {len(df)} films, {len(df.columns)} columns")
df.info()
# Out:
# Combined dataset: 50000 films, 61 columns
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 61 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   titleId               50000 non-null  str
#  1   imdbUrl               50000 non-null  str
#  2   originalTitle         50000 non-null  str
#  3   titleType             50000 non-null  str
#  4   releaseYear           45808 non-null  float64
#  5   runtimeMinutes        36448 non-null  float64
#  6   isAdult               50000 non-null  bool
#  7   imdbRating            26352 non-null  float64
#  8   numberOfVotes         26352 non-null  float64
#  9   allCountries          50000 non-null  str
#  10  mainCountry           50000 non-null  str
#  11  allLanguages          45727 non-null  str
#  12  firstLanguage         45727 non-null  str
#  13  englishTitle          15144 non-null  str
#  14  topFiveActors         38820 non-null  str
#  15  directors             46718 non-null  str
#  16  writers               39744 non-null  str
#  17  plotShort             22778 non-null  str
#  18  plotMedium            18008 non-null  str
#  19  plotLong              2033 non-null   str
#  20  genres                45440 non-null  str
#  21  keywords              26586 non-null  str
#  22  production            42863 non-null  str
#  23  tmdb_id               27646 non-null  float64
#  24  budget                27646 non-null  float64
#  25  revenue               27646 non-null  float64
#  26  tmdb_popularity       27646 non-null  float64
#  27  tmdb_vote_average     27646 non-null  float64
#  28  tmdb_vote_count       27646 non-null  float64
#  29  original_language     27646 non-null  str
#  30  tagline               4297 non-null   str
#  31  status                27646 non-null  str
#  32  spoken_languages      23524 non-null  str
#  33  production_countries  23255 non-null  str
#  34  aggregateRating       26761 non-null  float64
#  35  totalVotes            48949 non-null  float64
#  36  rating_1              26761 non-null  float64
#  37  rating_2              26761 non-null  float64
#  38  rating_3              26761 non-null  float64
#  39  rating_4              26761 non-null  float64
#  40  rating_5              26761 non-null  float64
#  41  rating_6              26761 non-null  float64
#  42  rating_7              26761 non-null  float64
#  43  rating_8              26761 non-null  float64
#  44  rating_9              26761 non-null  float64
#  45  rating_10             26761 non-null  float64
#  46  ml_rating_count       453 non-null    float64
#  47  ml_rating_mean        453 non-null    float64
#  48  ml_rating_std         445 non-null    float64
#  49  ml_rating_median      453 non-null    float64
#  50  ml_rating_0_5         453 non-null    float64
#  51  ml_rating_1_0         453 non-null    float64
#  52  ml_rating_1_5         453 non-null    float64
#  53  ml_rating_2_0         453 non-null    float64
#  54  ml_rating_2_5         453 non-null    float64
#  55  ml_rating_3_0         453 non-null    float64
#  56  ml_rating_3_5         453 non-null    float64
#  57  ml_rating_4_0         453 non-null    float64
#  58  ml_rating_4_5         453 non-null    float64
#  59  ml_rating_5_0         453 non-null    float64
#  60  ml_tags               412 non-null    str
# dtypes: bool(1), float64(36), str(24)
# memory usage: 22.9 MB

# %% [markdown]
# ## 3. Coverage Overview
#
# How much data do we actually have across sources?

# %%
coverage = pd.DataFrame({
    "Source": ["Original (IMDb metadata)", "TMDb (found)", "TMDb (has budget or revenue)",
              "IMDb histograms", "MovieLens (ratings)", "MovieLens (tags)",
              "All 3 enrichment sources"],
    "Films": [
        len(df),
        df["tmdb_id"].notna().sum(),
        ((df["budget"].fillna(0) > 0) | (df["revenue"].fillna(0) > 0)).sum(),
        df["totalVotes"].notna().sum(),
        df["ml_rating_count"].notna().sum(),
        df["ml_tags"].notna().sum(),
        ((df["tmdb_id"].notna()) & (df["totalVotes"].notna()) & (df["ml_rating_count"].notna())).sum(),
    ]
})
coverage["Coverage"] = (coverage["Films"] / len(df) * 100).round(1).astype(str) + "%"
coverage
# Out:
#                          Source  Films Coverage
# 0      Original (IMDb metadata)  50000   100.0%
# 1                  TMDb (found)  27646    55.3%
# 2  TMDb (has budget or revenue)   2572     5.1%
# 3               IMDb histograms  48949    97.9%
# 4           MovieLens (ratings)    453     0.9%
# 5              MovieLens (tags)    412     0.8%
# 6      All 3 enrichment sources    451     0.9%

# %%
fig, ax = plt.subplots(figsize=(10, 4))
bars = ax.barh(coverage["Source"], coverage["Films"], color="steelblue")
ax.set_xlabel("Number of films")
ax.set_title("Data Coverage by Source (out of 2,000 films)")
ax.axvline(x=2000, color="gray", linestyle="--", alpha=0.5)
for bar, val in zip(bars, coverage["Films"]):
    ax.text(bar.get_width() + 20, bar.get_y() + bar.get_height()/2,
            f"{val:,}", va="center", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. New Columns Explained
#
# ### From TMDb
# | Column | Description |
# |--------|-------------|
# | `budget` | Production budget in USD |
# | `revenue` | Worldwide box office revenue in USD |
# | `tmdb_popularity` | TMDb popularity score (views, watchlists, etc.) |
# | `tmdb_vote_average` | TMDb user rating (0-10) |
# | `tmdb_vote_count` | Number of TMDb user votes |
# | `original_language` | ISO language code |
# | `tagline` | Marketing tagline |
# | `production_countries` | ISO country codes |
#
# ### From IMDb Rating Distributions
# | Column | Description |
# |--------|-------------|
# | `rating_1` to `rating_10` | Number of IMDb users who gave each score |
# | `aggregateRating` | Weighted average (same as `imdbRating`) |
# | `totalVotes` | Total votes (same as `numberOfVotes`) |
#
# ### From MovieLens
# | Column | Description |
# |--------|-------------|
# | `ml_rating_count` | Number of MovieLens ratings |
# | `ml_rating_mean` | Average MovieLens rating (0.5–5.0 scale) |
# | `ml_rating_std` | Standard deviation of ratings |
# | `ml_rating_median` | Median rating |
# | `ml_rating_0_5` to `ml_rating_5_0` | Ratings per half-star bucket |
# | `ml_tags` | User-contributed tags (comma-separated) |

# %% [markdown]
# ## 5. Quick Sanity Checks

# %%
# Do IMDb and TMDb ratings agree?
has_both = df[df["tmdb_vote_average"].notna() & df["imdbRating"].notna()].copy()

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].scatter(has_both["imdbRating"], has_both["tmdb_vote_average"], alpha=0.3, s=10)
axes[0].plot([0, 10], [0, 10], "r--", alpha=0.5)
axes[0].set_xlabel("IMDb Rating")
axes[0].set_ylabel("TMDb Rating")
axes[0].set_title("IMDb vs TMDb Ratings")

# Do IMDb and MovieLens ratings agree? (different scales: IMDb 1-10, ML 0.5-5)
has_ml = df[df["ml_rating_mean"].notna()].copy()
axes[1].scatter(has_ml["imdbRating"], has_ml["ml_rating_mean"] * 2, alpha=0.3, s=10)
axes[1].plot([0, 10], [0, 10], "r--", alpha=0.5)
axes[1].set_xlabel("IMDb Rating")
axes[1].set_ylabel("MovieLens Rating (scaled to 0-10)")
axes[1].set_title("IMDb vs MovieLens Ratings")

plt.tight_layout()
plt.show()

# %%
# Budget and revenue distributions
has_fin = df[(df["budget"].fillna(0) > 0) | (df["revenue"].fillna(0) > 0)].copy()

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

has_fin[has_fin["budget"] > 0]["budget"].apply(lambda x: x / 1e6).hist(
    bins=50, ax=axes[0], color="steelblue", edgecolor="white")
axes[0].set_xlabel("Budget (millions USD)")
axes[0].set_ylabel("Number of films")
axes[0].set_title(f"Budget Distribution (n={int((has_fin['budget'] > 0).sum())})")

has_fin[has_fin["revenue"] > 0]["revenue"].apply(lambda x: x / 1e6).hist(
    bins=50, ax=axes[1], color="coral", edgecolor="white")
axes[1].set_xlabel("Revenue (millions USD)")
axes[1].set_ylabel("Number of films")
axes[1].set_title(f"Revenue Distribution (n={int((has_fin['revenue'] > 0).sum())})")

plt.tight_layout()
plt.show()

# %%
# Example: rating distribution for a polarizing film
rating_cols = [f"rating_{i}" for i in range(1, 11)]

# Find most polarizing film with decent vote count
subset = df[df["totalVotes"] > 1000].copy()
subset["pct_extreme"] = (subset["rating_1"].fillna(0) + subset["rating_10"].fillna(0)) / subset["totalVotes"]
most_polar = subset.nlargest(1, "pct_extreme").iloc[0]

# Also pick a consensus film for comparison
subset["pct_middle"] = subset[[f"rating_{i}" for i in range(5, 9)]].sum(axis=1) / subset["totalVotes"]
most_consensus = subset.nlargest(1, "pct_middle").iloc[0]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, film, label in [(axes[0], most_polar, "Most Polarizing"), (axes[1], most_consensus, "Most Consensus")]:
    votes = [film[f"rating_{i}"] for i in range(1, 11)]
    ax.bar(range(1, 11), votes, color="steelblue", edgecolor="white")
    ax.set_xlabel("Rating")
    ax.set_ylabel("Vote count")
    title = film["englishTitle"] if pd.notna(film["englishTitle"]) else film["originalTitle"]
    ax.set_title(f"{label}: {title}\n(avg: {film['imdbRating']}, votes: {int(film['totalVotes']):,})")
    ax.set_xticks(range(1, 11))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Sample Tags from MovieLens
#
# MovieLens user tags give us thematic descriptors that go beyond genre labels.

# %%
# Show some example tags
tagged = df[df["ml_tags"].notna()][["originalTitle", "genres", "ml_tags"]].head(10)
for _, row in tagged.iterrows():
    tags = row["ml_tags"][:100] + ("..." if len(str(row["ml_tags"])) > 100 else "")
    print(f"{row['originalTitle']}")
    print(f"  Genres: {row['genres']}")
    print(f"  Tags:   {tags}")
    print()
# Out:
# Gran Torino
#   Genres: Drama
#   Tags:   Clint Eastwood, culture clash, friendship, heartwarming, racism, racist humor, comedy, drama, humoro...
#
# Travolti da un insolito destino nell'azzurro mare d'agosto
#   Genres: Adventure, Comedy, Drama
#   Tags:   bare breasts, BDSM, class society, communism, f rated, face slap, falling in love, husband wife rela...
#
# Colonia
#   Genres: Biography, Drama, History, Romance, Thriller
#   Tags:   1970s, based on a true story, chile, cult, liberal propaganda, pinochet, religious fanatic, emma wat...
#
# The Princess and the Goblin
#   Genres: Animation, Adventure, Comedy, Family, Fantasy, Horror, Musical, Romance
#   Tags:   animation, goblin, princess, animated
#
# A Canterbury Tale
#   Genres: Comedy, Drama, Mystery, War
#   Tags:   Tumey's DVDs, AMERICANS ABROAD, atmospheric, earnest, heartwarming, LIFE ON THE HOMEFRONT, lyrical, ...
#
# In Her Shoes
#   Genres: Comedy, Drama, Romance
#   Tags:   Cameron Diaz, better than expected, family bonds, romantic, chick flick, dyslexia, self-help, romanc...
#
# La voz dormida
#   Genres: Drama, War
#   Tags:   Benito Zambrano, Inma Cuesta, Marc Clotet, María León, Spanish Civil War
#
# Macabro
#   Genres: Horror, Mystery, Thriller
#   Tags:   macabre, New Orleans, accident, blindness, dead child, disembodied head, mental illness, murder, nec...
#
# The Pillow Book
#   Genres: Drama
#   Tags:   artistic, beautifully filmed, Ewan McGregor, murder, Nudity (Full Frontal - Notable), romance, autob...
#
# Thriller - En grym film
#   Genres: Action, Crime, Drama, Horror, Thriller
#   Tags:   grindhouse, explicit sex scene, lesbian, male nudity, Nudity (Rear), revenge, unsimulated sex scenes...

# %% [markdown]
# ## 7. Save Combined Dataset

# %%
df.to_csv("../03-data/films_enriched.csv", index=False)
print(f"Saved: {len(df)} films, {len(df.columns)} columns")
print(f"File: 03-data/films_enriched.csv")
# Out:
# Saved: 50000 films, 61 columns
# File: 03-data/films_enriched.csv

# %% [markdown]
# ## Summary
#
# We started with 2,000 European films and 23 columns of IMDb metadata. After enrichment, we have **61 columns** including:
#
# - **Financial data** (budget + revenue) for ~1,060 films from TMDb
# - **Rating distributions** (per-star vote counts) for 1,999 films from IMDb's GraphQL API
# - **User-level rating stats and tags** for ~1,593 films from MovieLens 32M
#
# ### Scripts used
# | Script | Source | API key needed? |
# |--------|--------|----------------|
# | `src/fetch_tmdb.py` | TMDb API | Yes (free at themoviedb.org) |
# | `src/fetch_imdb_ratings.py` | IMDb GraphQL API | No |
# | `src/fetch_movielens.py` | MovieLens 32M dataset | No (download zip) |
#
# ### Raw data files
# All raw enrichment files are stored in `03-data/raw/`:
# - `tmdb_enrichment.csv`
# - `imdb_rating_distributions.csv`
# - `movielens_enrichment.csv`
#
# The combined dataset is at `03-data/european_films_enriched.csv`.
#
# ### Limitations
# - **TMDb financial data is community-contributed** — coverage skews toward well-known films. ~47% of our films have no budget or revenue data.
# - **MovieLens users are not representative** — they skew younger, English-speaking, and more film-literate than general audiences.
# - **IMDb rating distributions are aggregated** — we know how many people gave a 10, but not who they are or their other ratings.
# - **Currency/inflation** — TMDb budget and revenue figures are nominal USD with no adjustment for inflation or purchasing power parity.
